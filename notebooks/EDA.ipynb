# %% [markdown]
# # Load the Insurance Claims Dataset
# This dataset contains insurance claims data, including customer details, claim amounts, and whether the claim was fraudulent.

# %%
 
import pandas as pd

# Load the dataset
df = pd.read_csv("../data/insurance_claims.csv")

# Show first 5 rows
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       10/17/2014           OH
# 1                 228   42         342868        6/27/2006           IN
# 2                 134   29         687698         9/6/2000           OH
# 3                 256   41         227811        5/25/1990           IL
# 4                 228   44         367455         6/6/2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %% [markdown]
# # Check for Missing Values
# Checking if any columns have missing values that might affect our analysis.

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %% [markdown]
# # Get Dataset Information
# This will show the structure of our dataset, including column names, data types, and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %% [markdown]
# # Get Summary Statistics
# This will provide insights into numerical columns, including mean, min, max, and standard deviation.

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %% [markdown]
# # Import Visualization Libraries
# I will use `matplotlib` and `seaborn` to create visualizations for better understanding of fraudulent claims.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set seaborn style for better visuals
sns.set_style("whitegrid")

# %% [markdown]
# # Count of Fraudulent vs. Non-Fraudulent Claims
# This bar chart shows the number of fraudulent vs. non-fraudulent claims.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set figure size
plt.figure(figsize=(6, 4))

# 🔹 **Added 'hue="fraud_reported"' to explicitly define the color grouping**
sns.countplot(data=df, x="fraud_reported", hue="fraud_reported", palette="coolwarm")

# Add labels and title
plt.xlabel("Fraudulent vs. Non-Fraudulent Claims")
plt.ylabel("Count")
plt.title("Count of Fraudulent vs. Non-Fraudulent Claims")

# Show plot
plt.show()

# %% [markdown]
# # Distribution of Total Claim Amounts
# This histogram shows the spread of total claim amounts to detect unusual high-value claims.

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["total_claim_amount"], bins=50, kde=True, color="blue")
plt.title("Distribution of Total Claim Amounts")
plt.xlabel("Claim Amount ($)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Boxplot of Claim Amounts
# This boxplot will help identify extreme outliers in claim amounts.

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df["total_claim_amount"], color="red")
plt.title("Boxplot of Claim Amounts")
plt.xlabel("Claim Amount ($)")
plt.show()

# %% [markdown]
# # Most Common Incident Types
# This bar chart shows which types of insurance claims are most common.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.countplot(
    y=df["incident_type"],  # Use 'y' for better readability
    order=df["incident_type"].value_counts().index,
    hue=df["incident_type"],  # Assign `hue` to the same variable
    palette="viridis",
    legend=False  # Remove legend since it’s redundant
)
plt.title("Most Common Incident Types")
plt.xlabel("Count")
plt.ylabel("Incident Type")
plt.show()
